# %% [markdown]
# <a href="https://colab.research.google.com/github/jessiepsx/DataScience-DIO/blob/main/ETL_com_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U google-genai

# %%
import time
import pandas as pd
from google import genai
from google.colab import userdata

# %%
api_key = userdata.get('GEMINI_API')
client = genai.Client(api_key=api_key)
model="gemini-2.5-flash"

# %% [markdown]
# #**Extract**

# %%
df = pd.read_csv('clientes.csv')
print(df)
# Out:
#    UserID            Nome            Banco   Saldo  Limite
# 0       1       Ana Silva  Banco do Brasil  1500.0    5000
# 1       2  Bruno Henrique             Itaú   250.5    1000
# 2       3  Carla Ferreira           Nubank    10.0     200

# %% [markdown]
# # **Transform**

# %%
def gerar_mensagem(cliente):
    prompt = (
        f"Aja como um redator publicitário bancário."
        f"Escreva APENAS uma frase curta (máximo 90 caracteres) para {cliente['Nome']} "
        f"sobre a importância de investir no banco {cliente['Banco']}. "
        f"não use quebras de linha e não dê explicações. Vá direto ao ponto. "
        )

    try:
        time.sleep(5)
        response = client.models.generate_content(
            model="gemini-2.5-flash",
            contents=prompt
        )

        return response.text.strip().replace('"', '')

    except Exception as e:
        return "Invista no seu futuro!"


# Execução
print("Gerando mensagens...")
df['MensagemPersonalizada'] = df.apply(gerar_mensagem, axis=1)

# Mostrar resultado
print(df[['Nome', 'MensagemPersonalizada']])
# Out:
# Gerando mensagens...
#              Nome                              MensagemPersonalizada
# 0       Ana Silva  Ana, seu futuro rende mais com investimentos n...
# 1  Bruno Henrique  Bruno Henrique, seu futuro campeão merece o me...
# 2  Carla Ferreira  Carla, seu dinheiro no Nubank: segurança, rent...

# %% [markdown]
# # **LOAD**

# %%
# Salva o resultado em um arquivo CSV
df.to_csv('marketing.csv', index=False, encoding='utf-8-sig')


from google.colab import files
files.download('marketing.csv')
